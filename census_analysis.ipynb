# %% [markdown]
# # Census Reports Data Analysis

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "daily_census_responses.csv"

# Read Purchasing File and store into Pandas data frame
census_data = pd.read_csv(file_to_load, encoding="latin1")

# %%
census_data.head()
# Out:
#     ID       Start time  Completion time                           Email  \
# 0  748  8/18/20 5:47:53  8/18/20 5:51:15      AMeier@krucialstaffing.com
# 1  749  8/18/20 5:52:13  8/18/20 5:52:13      Jcharo@krucialstaffing.com
# 2  750  8/18/20 5:53:21  8/18/20 5:56:51     mkelley@krucialstaffing.com
# 3  751  8/18/20 6:04:55  8/18/20 6:04:55  Dhernandez@krucialstaffing.com
# 4  752  8/18/20 6:06:00  8/18/20 6:08:23    droberts@krucialstaffing.com
#
#               Name                       Hotel    SHIFT  \
# 0     Anthea Meier           Motel 6 - Mission  A Shift
# 1       Josh Charo  Mainstay Suites - Edinburg  A Shift
# 2   Michael Kelley  Beach Resort - South Padre  A Shift
# 3  Devan Hernandez         Drury Inn - McAllen  A Shift
# 4  Dorrian Roberts      Fairfield Inn - Laredo  A Shift
#
#                                    Facility  New Arrivals  Pending Arrivals  \
# 0            Starr County Memorial Hospital             0                 0
# ...

# %% [markdown]
# Get the Hotels as a unique list for keys

# %%
hotels = pd.DataFrame(census_data["Hotel"].unique(), columns=['Hotel'])
hotels
# Out:
#                             Hotel
# 0               Motel 6 - Mission
# 1      Mainstay Suites - Edinburg
# 2      Beach Resort - South Padre
# 3             Drury Inn - McAllen
# 4          Fairfield Inn - Laredo
# ..                            ...
# 167        Hampton Inn - Amarillo
# 168   LaQuinta Airport - Amarillo
# 169              LaQuinta - Dumas
# 170  Staybridge Suites - Longview
# 171   Holiday Inn Express - Pampa
#
# [172 rows x 1 columns]

# %%
# Out:
#    Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                     179         $3.05                 780     $2,379.77

# %%
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
